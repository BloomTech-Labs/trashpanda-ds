# %% [markdown]
# # Binary Masks to COCO Annotation Format
#
# by _Tobias Reaper_
#
# The goal of this notebook is to use the binary masks created in the [previous notebook](03-png-to-binary-mask.ipynb) to create an annotated object detection dataset in the COCO format.
#
# Resources:
#
# - [Create your own COCO-style datasets](https://patrickwasp.com/create-your-own-coco-style-dataset/)
#
# Note:
#
# > Although the image dataset used in the notebooks in this repo is not huge, it is large enough that it is not included in this shared repository. The dataset before and after the conversion into the COCO format is available at [tobias-fyi/neurecycle](https://github.com/tobias-fyi/neurecycle/tree/master/pycoco)
#
# ---

# %%
# === Imports === #
import datetime
import json
import os
import re
import fnmatch
from PIL import Image
import numpy as np
from pycococreatortools import pycococreatortools

# %%
# === Directories === #
DATASET_NAME = "items_train2019"
ROOT_DIR = "/Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train"
IMAGE_DIR = os.path.join(ROOT_DIR, DATASET_NAME)
ANNOTATION_DIR = os.path.join(ROOT_DIR, "annotations")

# %%
# === MetaDataset === #

INFO = {
    "description": "Trash Panda Foreground Detection Sample Data",
    "url": "https://github.com/tobias-fyi/neurecycle/tree/master/pycoco/items/train",
    "version": "0.1.0",
    "year": 2019,
    "contributor": "tobias-fyi",
    "date_created": datetime.datetime.utcnow().isoformat(" ")
}

LICENSES = [
    {
        "id": 1,
        "name": "Attribution-NonCommercial-ShareAlike License",
        "url": "http://creativecommons.org/licenses/by-nc-sa/2.0/"
    }
]

CATEGORIES = [
    {"id": 1, "name": "cardboard", "supercategory": "item",},
    {"id": 2, "name": "glass_container", "supercategory": "item",},
    {"id": 3, "name": "metal_cans", "supercategory": "item",},
    {"id": 4, "name": "mixed_paper", "supercategory": "item",},
    {"id": 5, "name": "paper_treated", "supercategory": "item",},
    {"id": 6, "name": "plastic_bottle", "supercategory": "item",},
    {"id": 7, "name": "plastic_bubblewrap", "supercategory": "item",},
    {"id": 8, "name": "plastic_container_food", "supercategory": "item",},
    {"id": 9, "name": "plastic_film", "supercategory": "item",},
    {"id": 10, "name": "wrapper", "supercategory": "item",},
]

# %%
# === Helper functions === #
def filter_for_jpeg(root, files):
    """Filters out non-jpg or -jpeg files."""
    file_types = ["*.jpeg", "*.jpg"]
    file_types = r"|".join([fnmatch.translate(x) for x in file_types])
    files = [os.path.join(root, f) for f in files]
    files = [f for f in files if re.match(file_types, f)]

    return files


def filter_for_png(root, files):
    """Returns only .png files"""
    file_types = ["*.png"]
    file_types = r"|".join([fnmatch.translate(x) for x in file_types])
    files = [os.path.join(root, f) for f in files]
    files = [f for f in files if re.match(file_types, f)]

    return files


def filter_for_annotations(root, files, image_filename):
    file_types = ["*.png"]
    file_types = r"|".join([fnmatch.translate(x) for x in file_types])
    basename_no_extension = os.path.splitext(os.path.basename(image_filename))[0]
    file_name_prefix = basename_no_extension + ".*"
    files = [os.path.join(root, f) for f in files]
    files = [f for f in files if re.match(file_types, f)]
    files = [
        f
        for f in files
        if re.match(file_name_prefix, os.path.splitext(os.path.basename(f))[0])
    ]

    return files

# %%
def create_annotations():

    coco_output = {
        "info": INFO,
        "licenses": LICENSES,
        "categories": CATEGORIES,
        "images": [],
        "annotations": [],
    }

    image_id = 1
    segmentation_id = 1

    # Filter for png images
    for root, _, files in os.walk(IMAGE_DIR):
        image_files = filter_for_png(root, files)

        # Loop through each image
        for image_filename in image_files:
            image = Image.open(image_filename)
            image_info = pycococreatortools.create_image_info(
                image_id, os.path.basename(image_filename), image.size
            )
            coco_output["images"].append(image_info)

            # Filter for associated png annotations
            for root, _, files in os.walk(ANNOTATION_DIR):
                annotation_files = filter_for_annotations(root, files, image_filename)

                # Go through each associated annotation
                for annotation_filename in annotation_files:

                    print(annotation_filename)
                    class_id = [
                        x["id"] for x in CATEGORIES if x["name"] in annotation_filename
                    ][0]

                    category_info = {
                        "id": class_id,
                        "is_crowd": "crowd" in image_filename,
                    }
                    binary_mask = np.asarray(
                        Image.open(annotation_filename).convert("1")
                    ).astype(np.uint8)

                    annotation_info = pycococreatortools.create_annotation_info(
                        segmentation_id,
                        image_id,
                        category_info,
                        binary_mask,
                        image.size,
                        tolerance=2,
                    )

                    if annotation_info is not None:
                        coco_output["annotations"].append(annotation_info)

                    segmentation_id += 1

            image_id += 1

    with open(f"{ROOT_DIR}/instances_{DATASET_NAME}.json", "w") as output_json_file:
        json.dump(coco_output, output_json_file)

# %%
# === Send it! === #
create_annotations()
# Out:
# cardboard_0233.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0237_cardboard_0237.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0223_cardboard_0223.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0009_metal_cans_0009.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0035_metal_cans_0035.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0021_metal_cans_0021.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0182_glass_container_0182.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0196_glass_container_0196.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0169_glass_container_0169.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0141_wrapper_0141.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0155_wrapper_0155.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0380_plastic_bubblewrap_0380.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0394_plastic_container_food_0394.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0419_plastic_container_food_0419.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0343_plastic_bottle_0343.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0425_plastic_container_food_0425.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0431_plastic_container_food_0431.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0357_plastic_bottle_0357.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0430_plastic_container_food_0430.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0356_plastic_bottle_0356.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0342_plastic_bottle_0342.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0424_plastic_container_food_0424.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0418_plastic_container_food_0418.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0395_plastic_container_food_0395.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0381_plastic_bubblewrap_0381.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0154_wrapper_0154.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0140_wrapper_0140.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0168_glass_container_0168.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0197_glass_container_0197.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0183_glass_container_0183.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0020_metal_cans_0020.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0034_metal_cans_0034.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0008_metal_cans_0008.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0222_cardboard_0222.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0236_cardboard_0236.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0208_cardboard_0208.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0220_cardboard_0220.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0234_cardboard_0234.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0022_metal_cans_0022.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0036_metal_cans_0036.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0195_glass_container_0195.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0181_glass_container_0181.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0156_wrapper_0156.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0142_wrapper_0142.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0397_plastic_container_food_0397.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0383_plastic_bubblewrap_0383.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0368_plastic_bottle_0368.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0354_plastic_bottle_0354.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0432_plastic_container_food_0432.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0426_plastic_container_food_0426.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0340_plastic_bottle_0340.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0427_plastic_container_food_0427.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0341_plastic_bottle_0341.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0355_plastic_bottle_0355.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0433_plastic_container_food_0433.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0369_plastic_bottle_0369.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0382_plastic_bubblewrap_0382.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0396_plastic_container_food_0396.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0143_wrapper_0143.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0157_wrapper_0157.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0180_glass_container_0180.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0194_glass_container_0194.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0037_metal_cans_0037.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0023_metal_cans_0023.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0235_cardboard_0235.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0221_cardboard_0221.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0209_cardboard_0209.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0285_mixed_paper_0285.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0291_mixed_paper_0291.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0246_cardboard_0246.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0252_cardboard_0252.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0087_plastic_film_0087.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0093_plastic_film_0093.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0044_metal_cans_0044.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0050_metal_cans_0050.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0078_metal_cans_0078.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0130_paper_treated_0130.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0124_plastic_film_0124.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/0118_plastic_film_0118.png
# /Users/Tobias/workshop/buildbox/neurecycle/pycoco/items/train/annotations/